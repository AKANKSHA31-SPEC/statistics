# %% [markdown]
# # STATISTICS.....5 DECEMBER

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.array([1,2,3,4,5,6,7])
b=np.array([1,2,3,4,5,6,7])

# %%
plt.title("linear line")
plt.xlabel("a")
plt.ylabel("b")
plt.plot(a,b)
plt.show()

# %%
g=np.array([30,40,50,60,70,80,90])
h=np.array([30,40,50,60,70,80,90])

# %%
#plt.title("Linear line")
plt.xlabel("g")
plt.ylabel("h")
plt.plot(g,h)
plt.show()

# %%
d=np.array([4,5,2,77,45,13,72,56,20])
e=np.array([2,13,22,25,10,20,15,40,33])

# %%
plt.title("INCOME & EPENDITURE GRAPH")
plt.xlabel("d")
plt.ylabel("e")
plt.plot(d,e)
plt.show()

# %%
plt.plot(d,e,'--r')   #r represent the red color
plt.show()

# %%
x=[5,10,20,25]
y=[10,15,5,12]

# %%
plt.title('BAR GRAPH')
plt.xlabel('x')
plt.ylabel('y')
plt.bar(x,y)
plt.show()

# %%
plt.bar?    #show internal data of the bar graph

# %%
u=[7,10,13,19,24,28,15,20,25]
v=[22,10,5,30,35,24,12,20,25]

# %%
plt.title("PROFIT-LOSS GRAPH")
plt.xlabel('u-axis')
plt.ylabel('v-axis')
plt.bar(u,v,color='r',align='center')
plt.show()

# %%
a=np.array([22,87,5,42,33,24,17,55,39,60,43,72,25])
plt.hist(a,bins=[0,20,40,60,80,100])
plt.title("histogram")
plt.show()

# %%
import pandas as pd
df=pd.read_csv('student_marks.csv')  #we make file like as student_marks on ms-excel and save into c drive in users but firstly we check  with the help of %cd  that what the path and where it store.
print(df)   # after that change file name and below the bar search csv machintost and save the file.
# Out:
#   STUDENTS  ROLLNO  MARKS GRADE  PERCENTAGE
# 0   RITESH      23     67     C          67
# 1    POOAM      42     89     B          89
# 2     RITU      13     90     A          90
# 3  SANJEEV      25     76     B          76
# 4    RAJUL      32     99     A          99

# %%
plt.hist(df['MARKS'],bins=10)
plt.title('Marks Histogram')
plt.show()

# %%
plt.boxplot(df['MARKS'])
plt.show()

# %%
plt.violinplot(df['MARKS'])
plt.show()

# %% [markdown]
# # SCATTER CODE

# %%
g=df['MARKS']
h=df['ROLLNO']
plt.xlabel('MARKS')
plt.ylabel('ROLLNO')
plt.scatter(x,y)
plt.show()

# %%
i=np.array([4,10,16,30,24,2,46,33,18])
j=np.array([9,22,32,16,18,45,38,29,2])
plt.xlabel('i')
plt.ylabel('j')
plt.scatter(i,j)
plt.show()

# %% [markdown]
# # SEABORN VISUALIZATION LIBRARY

# %%
#import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
x=['sun','mon','tue','wed','thurs','fri','sat']
y=[5,6.2,4,5.5,3,7,4.4]

# %%
ax=sns.stripplot(x,y)
ax.set(xlabel='Days',ylabel='Amount_spend')
plt.title('My First Graph')
plt.show()

# %%
sns.violinplot?

# %%
ds=pd.read_csv('student_marks.csv')
print(ds.head())
sns.violinplot(x="MARKS",data=ds)
plt.show()
# Out:
#   STUDENTS  ROLLNO  MARKS GRADE  PERCENTAGE
# 0   RITESH      23     67     C          67
# 1    POOAM      42     89     B          89
# 2     RITU      13     90     A          90
# 3  SANJEEV      25     76     B          76
# 4    RAJUL      32     99     A          99

# %% [markdown]
# # DOUBT

# %%
#import pandas as pd
#import seaborn as sns
dsiris=pd.read_csv('iris.csv')
print(dsiris)
print(dsiris.head())
#ax=sns.stripplot(x,y)
sns.set(style="whitegrid")
ax=sns.stripplot(x='class',y='sepal length',data=dsiris)
plt.title('Graph')
plt.show()
# Out:
#    Unnamed: 0   SEPAL LENGTH  Unnamed: 2  SEPAL WIDTH  Unnamed: 4  \
# 0           1            5.1         NaN          3.5         NaN
# 1           2            4.9         NaN          3.0         NaN
# 2          50            6.4         NaN          3.5         NaN
# 3         150            5.9         NaN          3.0         NaN
#
#    PETAL LENGTH  Unnamed: 6  PETAL WIDTH  Unnamed: 8 CLASS LABEL
# 0           1.4         NaN          0.2         NaN      Setosa
# 1           1.4         NaN          0.2         NaN      setosa
# 2           4.5         NaN          1.2         NaN  versicolor
# 3           5.0         NaN          1.8         NaN   verginica
#    Unnamed: 0   SEPAL LENGTH  Unnamed: 2  SEPAL WIDTH  Unnamed: 4  \
# 0           1            5.1         NaN          3.5         NaN
# 1           2            4.9         NaN          3.0         NaN
# 2          50            6.4         NaN          3.5         NaN
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
flights=sns.load_dataset('flights')
flights.head(5)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights.passengers.hist(bins=5)
plt.show()

# %%
flights.passengers.describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers, dtype: float64

# %%
sns.boxplot(x=flights.passengers)
plt.show()

# %%
titanicds=sns.load_dataset("titanic")
print(titanicds)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanicds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanicds['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): [First, Second, Third]

# %%
titanicds['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(titanicds['class'])
plt.show()

# %%
sns.catplot?

# %%
g=sns.catplot(x="class",y="survived",hue="sex",data=titanicds,kind="bar")
plt.show()

# %%
g=sns.catplot(x="class",y="survived",hue="sex",data=titanicds,kind="violin")
plt.show()

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
sns.set(style="ticks")
exercise=sns.load_dataset("exercise")
g=sns.catplot(x="time",y="pulse", hue="kind",data=exercise)

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
tips=sns.load_dataset("tips")
print(tips.head())
sns.violinplot(x="total_bill",data=tips)
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot?

# %%
sns.distplot(tips["tip"],bins=20)
plt.show()

# %%
sns.distplot(tips["total_bill"])
plt.show()

# %%
sns.distplot(tips["total_bill"],bins=100)
plt.show()

# %%
sns.distplot(tips["total_bill"],bins=50,kde=False)
plt.show()

# %%
irisds=sns.load_dataset("iris")
irisds
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
sns.set()
sns.set_context("paper")
iris=sns.load_dataset("iris")
sns.swarmplot(x="species", y="petal_length",data=iris)
plt.show()

# %%
sns.get_dataset_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
mpgds=sns.load_dataset('mpg')
mpgds
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.scatterplot(data=mpgds,x='mpg',y='weight')
plt.show()

# %%
sns.scatterplot(data=mpgds, x='horsepower',y='mpg')
plt.show()

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg')
plt.show()

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg',kind='kde')
plt.show()

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg',kind='hex')
plt.show()

# %%
sns.stripplot(data=mpgds,x='origin',y='mpg')
plt.show()

# %%
sns.swarmplot(data=mpgds,x='origin',y='mpg')
plt.show()

# %%
sns.catplot?

# %%
sns.catplot(data=mpgds,x='origin',y='mpg',kind='box')
plt.show()

# %%
sns.pairplot(mpgds)
plt.show()

# %%
sns.heatmap?

# %%
flights=sns.load_dataset("flights")
flights=flights.pivot("month","year","passengers")
flights
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
#sns.heatmap?
ax=sns.heatmap(flights)

# %% [markdown]
# # FINISHED
